# %%
from magnet import Base

tables = [x for x in Base.metadata.tables.values()]

arr = []

for table in tables:
    """
    'key', 
    'name',
    'table',
    'type',
    'is_literal',
    'primary_key',
    'nullable',
    'default',
    'server_default',
    'server_onupdate',
    'index',
    'unique',
    'system',
    'doc',
    'onupdate',
    'autoincrement',
    'constraints',
    'foreign_keys',
    'comment',
    'computed',
    '_creation_order',
    'dispatch',
    'proxy_set',
    'description',
    'comparator',
    '_cloned_set',
    '_from_objects',
    '_label',
    '_key_label',
    '_render_label_in_columns_clause'
    """
    
    arr.append("## " + table.name)
    if table.comment:
        arr.append(table.comment)
    arr.append("| name | type | pk | nullable | default | unique | comment |")
    arr.append("| :--- | :---: | :---: | :---: | :---: | :---: | ---: |")
    for column in table._columns.values():
        
        try:
            str_type = str(column.type)
        except:
            str_type = "多分JSON"
        
        try:
            default = column.default.default
        except:
            default = ""
            
        s = "| {name} | {type} | {pk} | {nullable} | {default} | {unique} | {comment} |".format(
            name=column.name,
            type=str_type,
            pk=column.primary_key,
            nullable=column.nullable,
            default=default,
            unique=column.unique,
            comment=column.index,
        )
        arr.append(s)
        
    arr.append("")

print("\n".join(arr))
# Out:
# ## case_node
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | name | VARCHAR(255) | False | False |  | None | None |
# | is_system | BOOLEAN | False | False |  | None | None |
# | description | VARCHAR(255) | False | False |  | None | None |
#
# ## target
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | name | VARCHAR(255) | False | False |  | None | None |
# | node_id | INTEGER | False | True |  | None | None |
#
# ## users
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | username | VARCHAR | False | True |  | True | True |
# | hashed_password | VARCHAR | False | True |  | None | None |
# | email | VARCHAR | False | True |  | True | True |
# | full_name | VARCHAR | False | True |  | None | None |
# | disabled | BOOLEAN | False | True |  | None | None |
# | is_active | BOOLEAN | False | True |  | None | None |
# | is_test | BOOLEAN | False | True |  | None | None |
#
# ## items
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | title | VARCHAR | False | True |  | None | True |
# | description | VARCHAR | False | True |  | None | True |
# | owner_id | INTEGER | False | True |  | None | None |
#
# ## keywords
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | category_name | VARCHAR | False | True |  | True | True |
# | tag | VARCHAR | False | True |  | None | True |
# | max_size | INTEGER | False | True |  | None | None |
#
# ## executor
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | is_system | BOOLEAN | False | False |  | None | None |
# | name | VARCHAR | False | True |  | None | None |
# | description | VARCHAR | False | False |  | None | None |
# | executor_name | VARCHAR | False | False |  | None | None |
# | pipeline_name | VARCHAR | False | False |  | None | None |
#
# ## executor_job
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | pipeline | VARCHAR(255) | False | True |  | None | None |
# | crawler_name | VARCHAR(255) | False | True |  | None | None |
# | keyword | VARCHAR(255) | False | True |  | None | None |
# | option_keywords | 多分JSON | False | False |  | None | None |
# | deps | INTEGER | False | False |  | None | None |
#
# ## __crypto_ohlc_daily
# 外部データソースから取得したチャート
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | provider | VARCHAR(255) | False | False |  | None | None |
# | market | VARCHAR(255) | False | False |  | None | None |
# | product | VARCHAR(255) | False | False |  | None | None |
# | periods | INTEGER | False | False |  | None | None |
# | close_time | DATETIME | False | False |  | None | None |
# | open_price | FLOAT | False | False |  | None | None |
# | high_price | FLOAT | False | False |  | None | None |
# | low_price | FLOAT | False | False |  | None | None |
# | close_price | FLOAT | False | False |  | None | None |
# | volume | FLOAT | False | False |  | None | None |
# | quote_volume | FLOAT | False | False |  | None | None |
# | t_sma_5 | FLOAT | False | False |  | None | None |
# | t_sma_10 | FLOAT | False | False |  | None | None |
# | t_sma_15 | FLOAT | False | False |  | None | None |
# | t_sma_20 | FLOAT | False | False |  | None | None |
# | t_sma_25 | FLOAT | False | False |  | None | None |
# | t_sma_30 | FLOAT | False | False |  | None | None |
# | t_sma_200 | FLOAT | False | False |  | None | None |
# | t_cross | INTEGER | False | False |  | None | None |
#
# ## __topic
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | referer | VARCHAR(1023) | False | True |  | None | None |
# | url | VARCHAR(1023) | False | True |  | None | None |
# | url_cache | VARCHAR(1023) | False | True |  | None | None |
# | title | VARCHAR(1023) | False | True |  | None | None |
# | summary | VARCHAR(1023) | False | True |  | None | None |
# | memo | VARCHAR(1023) | False | False |  | None | None |
# | detail | 多分JSON | False | False |  | None | None |
#
# ## trade_profile
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | name | VARCHAR(255) | False | False |  | None | None |
# | description | VARCHAR(1024) | False | False |  | None | None |
# | provider | VARCHAR(255) | False | False |  | None | None |
# | market | VARCHAR(255) | False | False |  | None | None |
# | product | VARCHAR(255) | False | False |  | None | None |
# | periods | INTEGER | False | False |  | None | None |
# | cron | VARCHAR(255) | False | False |  | None | None |
# | broker | VARCHAR(255) | False | False |  | None | None |
# | order_id | FLOAT | False | True |  | None | None |
# | trade_rule | 多分JSON | False | False |  | None | None |
#
# ## trade_job
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | name | VARCHAR(255) | False | False |  | None | None |
# | description | VARCHAR(1024) | False | False |  | None | None |
# | provider | VARCHAR(255) | False | False |  | None | None |
# | market | VARCHAR(255) | False | False |  | None | None |
# | product | VARCHAR(255) | False | False |  | None | None |
# | periods | INTEGER | False | False |  | None | None |
# | cron | VARCHAR(255) | False | False |  | None | None |
# | broker | VARCHAR(255) | False | False |  | None | None |
# | order_id | FLOAT | False | True |  | None | None |
# | trade_rule | 多分JSON | False | False |  | None | None |
#
# ## ingester_jobgroup
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | is_system | BOOLEAN | False | False |  | None | None |
# | description | VARCHAR(1023) | False | False |  | None | None |
# | target_id | INTEGER | False | True |  | None | None |
#
# ## ingester_job
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | parent_id | INTEGER | False | True |  | None | None |
# | description | VARCHAR(1023) | False | False |  | None | None |
# | pipeline_name | VARCHAR(255) | False | True |  | None | None |
# | crawler_name | VARCHAR(255) | False | True |  | None | None |
# | keyword | VARCHAR(255) | False | True |  | None | None |
# | option_keywords | 多分JSON | False | False |  | None | None |
# | deps | INTEGER | False | False |  | None | None |
#
# ## ingester
# | name | type | pk | nullable | default | unique | comment |
# | :--- | :---: | :---: | :---: | :---: | :---: | ---: |
# | id | INTEGER | True | False |  | None | None |
# | parent_id | INTEGER | False | True |  | None | None |
# | pipeline_name | VARCHAR(255) | False | True |  | None | None |
# | crawler_name | VARCHAR(255) | False | True |  | None | None |
# | keyword | VARCHAR(255) | False | True |  | None | None |
# | option_keywords | 多分JSON | False | False |  | None | None |
# | deps | INTEGER | False | False |  | None | None |
# | referer | VARCHAR(1023) | False | True |  | None | None |
# | url | VARCHAR(1023) | False | True |  | None | None |
# | url_cache | VARCHAR(1023) | False | True |  | None | None |
# | title | VARCHAR(1023) | False | True |  | None | None |
# | summary | VARCHAR(1023) | False | True |  | None | None |
# | current_page_num | INTEGER | False | False |  | None | None |
# | detail | 多分JSON | False | False |  | None | None |
